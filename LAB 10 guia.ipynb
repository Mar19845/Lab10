# %% [markdown]
# # Clasificación de rótulos de tránsito (EEUU) utilizando la arquitectura de CNN Le_Net

# %% [markdown]
# # Enunciado del problema

# %% [markdown]
# A lo largo del tiempo, se han desarrollado muchas arquitecturas de redes neuronales, algunas de ellas se han vuelto clásicas.  Una de ellas es una CNN (red neuronal convolucional) desarrollada por Yann LeCun a la que le denominó Le-Net.  Pueden ver el artículo original en:
#
# http://yann.lecun.com/exdb/publis/pdf/lecun-01a.pdf
#
# El diseño es el siguiente:
#
# ![Arquitectura Le-Net](../Images/Le-Net.png)
#
# * C: Capa de Convolución,
# * S: Capa de Submuestreo (Pooling),
# * F: Capa completamente conectada (Fully Connected)

# %% [markdown]
# En este caso de estudio, se proveen imágenes de rótulos de tráfico y el objetivo es entrenar una red Le-Net para que las pueda clasificar
#
# - El conjunto de datos contiene 43 clases diferentes de imágenes.
# - Las clases se listan abajo:
#
#     0 - Limite velocidad (20km/h)
#     1 - Limite velocidad (30km/h)
#     2 - Limite velocidad (50km/h)
#     3 - Limite velocidad (60km/h)
#     4 - Limite velocidad (70km/h)
#     5 - Limite velocidad (80km/h)
#     6 - Fin de limite velocidad (80km/h)'
#     7 - Limite velocidad (100km/h)
#     8 - Limite velocidad (120km/h)
#     9 - No rebasar
#     10 - No rebasar para vehiculos mayores de 3.5 tonladas metricas
#     11 - Derecho-de-via en la siguiente interseccion
#     12 - Camino prioritario
#     13 - Ceda el paso
#     14 - Alto
#     15 - No vehiculos
#     16 - Prohibido vehiculos mayores de 3.5 toneladas metricas
#     17 - No hay entrada
#     18 - Precaucion general
#     19 - Curva peligrosa a la izquierda
#     20 - Curva peligrosa a la derecha
#     21 - Doble curva
#     22 - Camino disparejo
#     23 - Camino resbaloso
#     24 - Camino se reduce a la derecha
#     25 - Trabajos adelante
#     26 - Señales de Trafico -semaforos-
#     27 - Cruce de peatones
#     28 - Cruce de Niños
#     29 - Cruce de bicicletas
#     30 - Cuidado hielo/nieve
#     31 - Cruce de animales silvestres
#     32 - Fin de todos los limites de velocidad y rebase
#     33 - Gire a la derecha adelante
#     34 - Gire a la izquierda adelante
#     35 - Recto solo
#     36 - Vaya recto o a la rerecha
#     37 - Vaya recto o a la izquierda
#     38 - Mantengase a la derecha
#     39 - Mantengase a la izquierda
#     40 - Vuelta en U obligada
#     41 - Fin de no rebasar
#     42 - Fin de no rebasar para vehiculos mayores de 3.5 toneladas metricas

# %% [markdown]
# Referencias (Señales de Tráfico)
#
# J. Stallkamp, M. Schlipsing, J. Salmen, and C. Igel. The German Traffic Sign Recognition Benchmark: A multi-class classification competition. In Proceedings of the IEEE International Joint Conference on Neural Networks, pages 1453–1460. 2011.
#
# @inproceedings{Stallkamp-IJCNN-2011,
#     author = {Johannes Stallkamp and Marc Schlipsing and Jan Salmen and Christian Igel},
#     booktitle = {IEEE International Joint Conference on Neural Networks},
#     title = {The {G}erman {T}raffic {S}ign {R}ecognition {B}enchmark: A multi-class classification competition},
#     year = {2011},
#     pages = {1453--1460}
# }

# %% [markdown]
# # IMPORTAR LIBRERIAS

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pickle
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random

# %% [markdown]
# # Obtener Datos
#
# El módulo de Pickle implementa protocolos binarios para la serialización y de-serialización de objetos Python

# %%
with open("entrenamiento.p", mode='rb') as datos_entreno:
    entreno = pickle.load(datos_entreno)
with open("validacion.p", mode='rb') as datos_validacion:
    valida = pickle.load(datos_validacion)
with open("prueba.p", mode='rb') as datos_prueba:
    prueba = pickle.load(datos_prueba)

# %%
X_entreno, y_entreno = entreno['features'], entreno['labels']
X_valida, y_valida = valida['features'], valida['labels']
X_prueba, y_prueba = prueba['features'], prueba['labels']

# %%
# TODO: numero de ejemplos de entreno
n_entreno = X_entreno.shape[0]

# TODO: numero de ejemplos de validacion
n_validacion = X_valida.shape[0]

# TODO: numero de ejemplos de prueba
n_prueba = X_prueba.shape[0]

# TODO: tamaño de las imagenes de señales de trancito  
image_shape = X_entreno.shape[1:4]

# TODO: numero de clases
n_classes = np.unique(ar=y_entreno).shape[0]

image_depth_dimension = X_entreno.shape[3]

print("Number of training examples =", n_entreno)
print("Number of testing examples =", n_prueba)
print("Image data shape =", image_shape)
print("Number of classes =", n_classes)
# Out:
# Number of training examples = 34799
# Number of testing examples = 12630
# Image data shape = (32, 32, 3)
# Number of classes = 43

# %% [markdown]
# # EXPLORACION DE LAS IMAGENES
#
# Mostrar que las imágenes no están "barajeadas"

# %%
import matplotlib.pyplot as plt
from random import randint

# %%
import matplotlib.pyplot as plt
from random import randint
#funcion qeu agrra las imagenes de los dataset y los muestra
def plot_digits(X, Y):
    # %matplotlib inline
    fig=plt.figure(figsize=(16, 16))
    columns = 9
    rows = 10
    for i in range(1, columns*rows +1):
        # show random images from the dataset
        img = X[randint(0, Y-1)]
        fig.add_subplot(rows, columns, i)
        plt.imshow(img)
        plt.axis('off')   
    plt.show()

# %% [markdown]
# #### DATOS ENTRENO

# %%
plot_digits(X_entreno, n_entreno)

# %%
fig, ax = plt.subplots(figsize=(12,8))
sns.countplot(y_entreno)
ax.set_title('Distribucion de imagenes', fontsize=14)
ax.set_xlabel('imagenes', fontsize=12)
ax.set_ylabel('cuenta', fontsize=14)
plt.show()

# %% [markdown]
# #### DATOS validacion

# %%
plot_digits(X_valida, n_validacion)

# %%
fig, ax = plt.subplots(figsize=(12,8))
sns.countplot(y_valida)
ax.set_title('Distribucion de imagenes', fontsize=14)
ax.set_xlabel('imagenes', fontsize=12)
ax.set_ylabel('cuenta', fontsize=14)
plt.show()

# %% [markdown]
# #### DATOS PRUEBA

# %%
plot_digits(X_prueba, n_prueba)

# %%
fig, ax = plt.subplots(figsize=(12,8))
sns.countplot(y_prueba)
ax.set_title('Distribucion de imagenes', fontsize=14)
ax.set_xlabel('imagenes', fontsize=12)
ax.set_ylabel('cuenta', fontsize=14)
plt.show()

# %% [markdown]
# # PREPARACION DE LOS DATOS

# %%
# "Barajear" los datos
random.shuffle(X_entreno)
random.shuffle(y_entreno)

# %%
# Convertir imágenes a blanco y negro
X_entreno = np.sum(X_entreno/3, axis=3, keepdims=True)
X_prueba  = np.sum(X_prueba/3, axis=3, keepdims=True)
X_valida  = np.sum(X_valida/3, axis=3, keepdims=True)

# %%
# TODO: numero de ejemplos de entreno
n_entreno = X_entreno.shape[0]

# TODO: numero de ejemplos de validacion
n_validacion = X_valida.shape[0]

# TODO: numero de ejemplos de prueba
n_prueba = X_prueba.shape[0]

# TODO: tamaño de las imagenes de señales de trancito  
image_shape = X_entreno.shape[1:4]

# TODO: numero de clases
n_classes = np.unique(ar=y_entreno).shape[0]

image_depth_dimension = X_entreno.shape[3]

print("Number of training examples =", n_entreno)
print("Number of testing examples =", n_prueba)
print("Image data shape =", image_shape)
print("Number of classes =", n_classes)
# Out:
# Number of training examples = 34799
# Number of testing examples = 12630
# Image data shape = (32, 32, 1)
# Number of classes = 43

# %%
# Normalizar los datos
def normalize(x):
    min_val = np.min(x)
    max_val = np.max(x)
    x = (x-min_val) / (max_val-min_val)
    return x

# %%
normalized_train = np.zeros([n_entreno,32,32,1])
normalized_validation = np.zeros([n_validacion,32,32,1])
normalized_test = np.zeros([n_prueba,32,32,1])
for i in range(0,n_entreno):
    normalized_train[i] = normalize(X_entreno[i])
for i in range(0,n_validacion):
    normalized_validation[i] = normalize(X_valida[i])
for i in range(0,n_prueba):
    normalized_test[i] = normalize(X_prueba[i])

assert(X_entreno.shape==normalized_train.shape)

# %% [markdown]
# ### Diferencia entre las imagenes normalizadas y las que no

# %%
f, axarr = plt.subplots(nrows=2,ncols=2,figsize = (10,10))
randomindex = randint(0,n_entreno-1)
axarr[0,0].imshow(X_entreno[randomindex])
axarr[0,0].axis('off')
axarr[0,0].set_title('Imagen Original')
axarr[0,1].imshow(normalized_train[randomindex])
axarr[0,1].axis('off')
axarr[0,1].set_title('Imagen Normalizada')
randomindex = randint(0,n_entreno-1)
axarr[1,0].imshow(X_entreno[randomindex])
axarr[1,0].axis('off')
axarr[1,0].set_title('Imagen Original')
axarr[1,1].imshow(normalized_train[randomindex])
axarr[1,1].axis('off')
axarr[1,1].set_title('Imagen Normalizada')
# Out:
# Text(0.5, 1.0, 'Imagen Normalizada')

# %% [markdown]
# ### Hacer que el conjunto de datos normalizado sea el conjunto que se usará en el modelo

# %%
X_entreno = normalized_train

X_validacion = normalized_validation

X_prueba = normalized_test

# %% [markdown]
# # Entrenamiento del modelo

# %% [markdown]
# El modelo consiste de las siguientes capas:
#
# - Paso 1: La primera capa convolucional #1
#
#     - Entrada = 32x32x1
#     - Salida = 28x28x6
#     - Salida = (Entrada-filtro+1)/Paso* => (32-5+1)/1=28
#     - Se utiliza un filtro de 5x5 con una profundidad de entrada 3 y profundidad de salida 6
#     - Aplicar una función de activación RELU a la salida
#     - Submuestreo (pooling) para la entrada, Entrada = 28x28x6 y Salida = 14x14x6
#
#
#     * Paso (Stride) es la cantidad por la cual el kernel se desplaza cuando el kernel se pasa sobre la imagen.
#
# - Paso 2: La segunda capa covolucional #2
#
#     - Entrada = 14x14x6
#     - Salida = 10x10x16
#     - Capa 2: Capa convolutional con salida = 10x10x16
#     - Output = (Input-filter+1)/strides => 10 = 14-5+1/1
#     - Aplicar una función de activación RELU a la salida
#     - Submuestreo (pooling) con Entrada = 10x10x16 Salida = 5x5x16
#
# - Paso 3: "Aplanar" la red (convertir a una dimensión)
#
#     - Entrada = 5x5x16 y Salida = 400
#
# - Paso 4: Capa plenamenente conectada
#
#     - Capa 3: Capa plenamente conectada con Entrada = 400 y Salida = 120
#     - Aplicar una función de activación RELU a la salida
#
# - Paso 5: Otra capa plenamente conectada
#
#     - Capa 4: Capa plenamente conectada con Entrada = 120 y Salida = 84
#     - Aplicar una función de activación RELU a la salida
#
# - Paso 6: Otra capa plenamente conectada
#
#     - Capa 5: Capa plenamente conectada con Entrada = 84 y Salida = 43

# %% [markdown]
# # Importar librerías para construir el modelo

# %%
from sklearn.model_selection import train_test_split
from keras.models import Sequential, load_model
from keras.layers import Conv2D, Dense, Flatten, Rescaling, AveragePooling2D, Dropout

# %%
# Crear el modelo
# Building the model
model = Sequential([
    Rescaling(1, input_shape=(32, 32, 1)),
    Conv2D(filters=6, kernel_size=(5, 5), activation='relu'),
    AveragePooling2D(pool_size=(2, 2)),
    Conv2D(filters=16, kernel_size=(5, 5), activation='relu'),
    AveragePooling2D(pool_size=(2, 2)),
    #Conv2D(filters=400, kernel_size=(5, 5), activation='relu'),
    Dropout(0.8), 
    Flatten(),
    Dense(units=120, activation='relu'),
    Dense(units=84, activation='relu'),
    Dense(units=43, activation='softmax')
])

# %%
# Compilar el modelo
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# Model architecture
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_3 (Rescaling)     (None, 32, 32, 1)         0
#
#  conv2d_6 (Conv2D)           (None, 28, 28, 6)         156
#
#  average_pooling2d_6 (Averag  (None, 14, 14, 6)        0
#  ePooling2D)
#
#  conv2d_7 (Conv2D)           (None, 10, 10, 16)        2416
#
#  average_pooling2d_7 (Averag  (None, 5, 5, 16)         0
#  ePooling2D)
#
#  dropout_2 (Dropout)         (None, 5, 5, 16)          0
#
#  flatten_3 (Flatten)         (None, 400)               0
#
#  dense_9 (Dense)             (None, 120)               48120
#
#  dense_10 (Dense)            (None, 84)                10164
#
#  dense_11 (Dense)            (None, 43)                3655
#
# =================================================================
# Total params: 64,511
# Trainable params: 64,511
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_entreno, y_entreno, epochs=50, validation_data=(X_prueba, y_prueba))
# Out:
# Epoch 1/50
# 1088/1088 [==============================] - 8s 7ms/step - loss: 3.4809 - accuracy: 0.0574 - val_loss: 3.4656 - val_accuracy: 0.0546
# Epoch 2/50
# 1088/1088 [==============================] - 8s 8ms/step - loss: 3.4806 - accuracy: 0.0562 - val_loss: 3.4650 - val_accuracy: 0.0594
# Epoch 3/50
# 1088/1088 [==============================] - 10s 9ms/step - loss: 3.4799 - accuracy: 0.0563 - val_loss: 3.4647 - val_accuracy: 0.0594
# Epoch 4/50
# 1088/1088 [==============================] - 9s 8ms/step - loss: 3.4802 - accuracy: 0.0551 - val_loss: 3.4646 - val_accuracy: 0.0594
# Epoch 5/50
# 1088/1088 [==============================] - 8s 7ms/step - loss: 3.4800 - accuracy: 0.0562 - val_loss: 3.4642 - val_accuracy: 0.0546
# Epoch 6/50
# 1088/1088 [==============================] - 8s 7ms/step - loss: 3.4798 - accuracy: 0.0576 - val_loss: 3.4645 - val_accuracy: 0.0546
# Epoch 7/50
# 1088/1088 [==============================] - 8s 8ms/step - loss: 3.4797 - accuracy: 0.0552 - val_loss: 3.4641 - val_accuracy: 0.0570
# Epoch 8/50
# 1088/1088 [==============================] - 9s 8ms/step - loss: 3.4798 - accuracy: 0.0554 - val_loss: 3.4634 - val_accuracy: 0.0546
# Epoch 9/50
# 1088/1088 [==============================] - 8s 8ms/step - loss: 3.4795 - accuracy: 0.0562 - val_loss: 3.4637 - val_accuracy: 0.0570
# Epoch 10/50
# 1088/1088 [==============================] - 8s 8ms/step - loss: 3.4795 - accuracy: 0.0555 - val_loss: 3.4643 - val_accuracy: 0.0570
# Epoch 11/50
# 1088/1088 [==============================] - 9s 8ms/step - loss: 3.4793 - accuracy: 0.0555 - val_loss: 3.4634 - val_accuracy: 0.0594
# Epoch 12/50
# 1088/1088 [==============================] - 9s 8ms/step - loss: 3.4792 - accuracy: 0.0544 - val_loss: 3.4638 - val_accuracy: 0.0594
# Epoch 13/50
# 1088/1088 [==============================] - 8s 8ms/step - loss: 3.4789 - accuracy: 0.0557 - val_loss: 3.4653 - val_accuracy: 0.0570
# Epoch 14/50
# 1088/1088 [==============================] - 8s 7ms/step - loss: 3.4789 - accuracy: 0.0573 - val_loss: 3.4631 - val_accuracy: 0.0594
# Epoch 15/50
# 1088/1088 [==============================] - 8s 7ms/step - loss: 3.4789 - accuracy: 0.0559 - val_loss: 3.4637 - val_accuracy: 0.0570
# Epoch 16/50
# 1088/1088 [==============================] - 8s 8ms/step - loss: 3.4788 - accuracy: 0.0571 - val_loss: 3.4640 - val_accuracy: 0.0546
# Epoch 17/50
# 1088/1088 [==============================] - 8s 8ms/step - loss: 3.4787 - accuracy: 0.0569 - val_loss: 3.4632 - val_accuracy: 0.0594
# Epoch 18/50
# 1088/1088 [==============================] - 8s 7ms/step - loss: 3.4790 - accuracy: 0.0569 - val_loss: 3.4636 - val_accuracy: 0.0594
# Epoch 19/50
# 1088/1088 [==============================] - 8s 8ms/step - loss: 3.4786 - accuracy: 0.0566 - val_loss: 3.4631 - val_accuracy: 0.0546
# Epoch 20/50
# 1088/1088 [==============================] - 9s 8ms/step - loss: 3.4784 - accuracy: 0.0558 - val_loss: 3.4638 - val_accuracy: 0.0570
# Epoch 21/50
# 1088/1088 [==============================] - 9s 8ms/step - loss: 3.4788 - accuracy: 0.0574 - val_loss: 3.4631 - val_accuracy: 0.0594
# Epoch 22/50
# 1088/1088 [==============================] - 9s 8ms/step - loss: 3.4785 - accuracy: 0.0560 - val_loss: 3.4636 - val_accuracy: 0.0570
# Epoch 23/50
# 1088/1088 [==============================] - 8s 8ms/step - loss: 3.4786 - accuracy: 0.0558 - val_loss: 3.4626 - val_accuracy: 0.0594
# Epoch 24/50
# 1088/1088 [==============================] - 8s 8ms/step - loss: 3.4784 - accuracy: 0.0576 - val_loss: 3.4631 - val_accuracy: 0.0570
# Epoch 25/50
# 1088/1088 [==============================] - 8s 7ms/step - loss: 3.4785 - accuracy: 0.0545 - val_loss: 3.4633 - val_accuracy: 0.0594
# Epoch 26/50
# 1088/1088 [==============================] - 8s 7ms/step - loss: 3.4785 - accuracy: 0.0554 - val_loss: 3.4631 - val_accuracy: 0.0570
# Epoch 27/50
# 1088/1088 [==============================] - 8s 7ms/step - loss: 3.4785 - accuracy: 0.0564 - val_loss: 3.4631 - val_accuracy: 0.0594
# Epoch 28/50
# 1088/1088 [==============================] - 8s 8ms/step - loss: 3.4784 - accuracy: 0.0582 - val_loss: 3.4628 - val_accuracy: 0.0594
# Epoch 29/50
# 1088/1088 [==============================] - 8s 7ms/step - loss: 3.4785 - accuracy: 0.0570 - val_loss: 3.4633 - val_accuracy: 0.0594
# Epoch 30/50
# 1088/1088 [==============================] - 9s 8ms/step - loss: 3.4784 - accuracy: 0.0571 - val_loss: 3.4626 - val_accuracy: 0.0570
# Epoch 31/50
# 1088/1088 [==============================] - 8s 7ms/step - loss: 3.4786 - accuracy: 0.0559 - val_loss: 3.4633 - val_accuracy: 0.0594
# Epoch 32/50
# 1088/1088 [==============================] - 8s 8ms/step - loss: 3.4784 - accuracy: 0.0575 - val_loss: 3.4630 - val_accuracy: 0.0570
# Epoch 33/50
# 1088/1088 [==============================] - 8s 8ms/step - loss: 3.4784 - accuracy: 0.0561 - val_loss: 3.4631 - val_accuracy: 0.0594
# Epoch 34/50
# 1088/1088 [==============================] - 8s 8ms/step - loss: 3.4783 - accuracy: 0.0574 - val_loss: 3.4640 - val_accuracy: 0.0570
# Epoch 35/50
# 1088/1088 [==============================] - 8s 8ms/step - loss: 3.4783 - accuracy: 0.0561 - val_loss: 3.4627 - val_accuracy: 0.0594
# Epoch 36/50
# 1088/1088 [==============================] - 8s 8ms/step - loss: 3.4785 - accuracy: 0.0562 - val_loss: 3.4628 - val_accuracy: 0.0546
# Epoch 37/50
# 1088/1088 [==============================] - 8s 8ms/step - loss: 3.4783 - accuracy: 0.0559 - val_loss: 3.4632 - val_accuracy: 0.0546
# Epoch 38/50
# 1088/1088 [==============================] - 8s 8ms/step - loss: 3.4785 - accuracy: 0.0553 - val_loss: 3.4640 - val_accuracy: 0.0594
# Epoch 39/50
# 1088/1088 [==============================] - 8s 8ms/step - loss: 3.4783 - accuracy: 0.0576 - val_loss: 3.4631 - val_accuracy: 0.0570
# Epoch 40/50
# 1088/1088 [==============================] - 8s 8ms/step - loss: 3.4782 - accuracy: 0.0564 - val_loss: 3.4633 - val_accuracy: 0.0546
# Epoch 41/50
# 1088/1088 [==============================] - 8s 8ms/step - loss: 3.4783 - accuracy: 0.0566 - val_loss: 3.4627 - val_accuracy: 0.0594
# Epoch 42/50
# 1088/1088 [==============================] - 8s 8ms/step - loss: 3.4782 - accuracy: 0.0548 - val_loss: 3.4629 - val_accuracy: 0.0570
# Epoch 43/50
# 1088/1088 [==============================] - 8s 8ms/step - loss: 3.4783 - accuracy: 0.0558 - val_loss: 3.4636 - val_accuracy: 0.0594
# Epoch 44/50
# 1088/1088 [==============================] - 8s 7ms/step - loss: 3.4783 - accuracy: 0.0577 - val_loss: 3.4632 - val_accuracy: 0.0594
# Epoch 45/50
# 1088/1088 [==============================] - 8s 8ms/step - loss: 3.4782 - accuracy: 0.0581 - val_loss: 3.4630 - val_accuracy: 0.0570
# Epoch 46/50
# 1088/1088 [==============================] - 8s 8ms/step - loss: 3.4783 - accuracy: 0.0560 - val_loss: 3.4625 - val_accuracy: 0.0594
# Epoch 47/50
# 1088/1088 [==============================] - 8s 8ms/step - loss: 3.4782 - accuracy: 0.0570 - val_loss: 3.4635 - val_accuracy: 0.0570
# Epoch 48/50
# 1088/1088 [==============================] - 8s 8ms/step - loss: 3.4782 - accuracy: 0.0561 - val_loss: 3.4634 - val_accuracy: 0.0594
# Epoch 49/50
# 1088/1088 [==============================] - 8s 7ms/step - loss: 3.4783 - accuracy: 0.0565 - val_loss: 3.4635 - val_accuracy: 0.0570
# Epoch 50/50
# 1088/1088 [==============================] - 8s 8ms/step - loss: 3.4783 - accuracy: 0.0560 - val_loss: 3.4629 - val_accuracy: 0.0570

# %% [markdown]
# # EVALUACION DEL MODELO

# %%
# Evaluar el modelo e indicar la exactitud con los datos de prueba
val_loss, val_acc = model.evaluate(X_prueba, y_prueba, verbose=2)
print('\Val accuracy:', val_acc)
print('\nValidation loss:', val_loss)
# Out:
# 395/395 - 1s - loss: 3.4629 - accuracy: 0.0570 - 779ms/epoch - 2ms/step
#
# Valifdation accuracy: 0.05700712651014328
#
# Validation loss: 3.4629437923431396

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# Generar gráfica de Exactitud y de Entrenamiento y Validación
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')

# %%
# Generar gráfica de Pérdida de Entrenamiento y Validación
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='lower right')

# %% [markdown]
# # Obtener las predicciones para los datos de prueba

# %%
#  A partir de la versión 2.6 de tensorflow, la siguiente instrucción
#    puede dar el error:  ‘Sequential’ object has no attribute ‘predict_classes’
#    por lo que se sustituye por la que le sigue
#
#clases_predichas = modelo_cnn.predict_classes(X_prueba_gris_norm)

clases_predichas = np.argmax(modelo_cnn.predict(X_prueba_BN_norm),axis=1)

# se obtienen los índices para poder graficar
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [56], in <cell line: 7>()
#       1 #  A partir de la versión 2.6 de tensorflow, la siguiente instrucción
#       2 #    puede dar el error:  ‘Sequential’ object has no attribute ‘predict_classes’
#       3 #    por lo que se sustituye por la que le sigue
#       4 #
#       5 #clases_predichas = modelo_cnn.predict_classes(X_prueba_gris_norm)
# ----> 7 clases_predichas = np.argmax(modelo_cnn.predict(X_prueba_BN_norm),axis=1)
#
# NameError: name 'modelo_cnn' is not defined

# %%
# Generar un mapa de calor para la matriz de confusión

# %%
# Generar un cuadro de 7 X 7 con los primeros 49 rótulos del conjunto de prueba y 
#   para cada uno colocar de título la etiqueta verdadera y el código predicho por el 
#   modelo

# %% [markdown]
# #  Ajustes del modelo
#
# Como se puede ver, hay muchos lugares donde se puede cambiar la configuración del modelo.  A continuación se sugieren varias posibilidades que deben probar e indicar si se mejora la exactitud del modelo:
#
# 1. Incrementar el número de épocas para el entrenamiento a 500 ó 1,000
# 2. En las capas de convolución cambiar el tamaño del kernel a 10 X 10
# 3. Cambiar el método de submuestrear (pooling) a MaxPooling
# 4. Cambiar el numero de la segunda capa plenamente conectada de 84 a 100 unidades
# 5. Cambiar el número de la primera capa plenamente conectada de 120 a 300 unidades
#
# La idea es ir haciendo los cambios uno por uno y ver cómo va cambiando la exactitud del modelo
